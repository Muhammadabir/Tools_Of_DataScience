# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Abir__
# Data Alanyst

# %% [markdown]
# *I got interested in Data from my final year thesis in my BSc Computer Science program*.
# *I saw how important data can be in decision making as well as some of the challanges it faces*.
# *However, it was the potentials as well as the job opportunities here in my country, that have made me get keen interest in it*.
# *I started and completed a full life cycle of Data Scince in my final year project without knowing much but being left inawe from what the tool allowed me to do*.
# *It created a strong curiosity towards it and from there on I wanted to learn more about it and undertand it better so that I could use machines to in decision making*.
# *The concept itself is very intreaging for me and I really want to see if that was how far I could go without knowing it well, how far can I go by actual studying it and mastering its understanding and implementation*.

# %% [markdown]
# ### The code below is a simple demonstration of python visualization

# %%
import matplotlib.pyplot as plot
x = [1, 2, 3]
y = [-1, -2, -3]

plot.title("This is a simple exaple of a linear graph")
plot.xlabel("This is x")
plot.ylabel("This is y")

plot.plot(x, y)
plot.show()

# %% [markdown]
# -------------------
# * **List, Image, Link:**
# 1. *List:*
# | The Library used |
# |------------------|
# |*Matplotlib*|
# |![This is Library](https://d33wubrfki0l68.cloudfront.net/e33fd6f372aa5d51e7b0de4bd763bd983251881e/4b0f4/blog/customising-matplotlib/matplot_title_logo.png)|
#
# 2. *Link:*
#
# [Lick here to learn more about Matplotlib](https://datatofish.com/line-chart-python-matplotlib/)
#
# 3. *Image:*
# Image: ![This is an Image](https://www.jumpingrivers.com/blog/customising-matplotlib/graphics/dark_plot-3.png)
